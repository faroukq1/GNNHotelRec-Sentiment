# %%
import pandas as pd

# %%
df = pd.read_csv('../results/gnn_balanced_results/gat/gat_results_balanced_improved_features.csv')

# %%
df.columns
# Out:
# Index(['timestamp', 'model', 'config_id', 'fold', 'hidden_dim', 'num_layers',
#        'heads', 'dropout', 'lr', 'weight_decay', 'train_acc', 'train_f1',
#        'train_mae', 'train_mse', 'train_rmse', 'val_acc', 'val_f1', 'val_mae',
#        'val_mse', 'val_rmse', 'test_acc', 'test_f1', 'test_mae', 'test_mse',
#        'test_rmse'],
#       dtype='object')

# %%
print(f"mae {df['test_mae'].idxmin()}")
print(df.iloc[163])
# Out:
# mae 163
# timestamp       2025-12-23T19:49:28.497318
# model                                  GAT
# config_id                               54
# fold                                     1
# hidden_dim                             256
# num_layers                               2
# heads                                    4
# dropout                                0.5
# lr                                   0.001
# weight_decay                           0.0
# train_acc                           0.6821
# train_f1                          0.682095
# train_mae                         0.635799
# train_mse                         1.271598
# train_rmse                        1.127652
# val_acc                           0.654444
# val_f1                            0.654442
# val_mae                           0.691113
# val_mse                           1.382225
# val_rmse                          1.175681
# test_acc                          0.656284
# test_f1                           0.656281
# ...

# %%
print(df['test_rmse'].idxmin())
print(df.iloc[100])
# Out:
# 100
# timestamp       2025-12-23T19:45:28.115413
# model                                  GAT
# config_id                               33
# fold                                     1
# hidden_dim                             128
# num_layers                               4
# heads                                    4
# dropout                                0.3
# lr                                  0.0005
# weight_decay                        0.0005
# train_acc                              0.0
# train_f1                               0.0
# train_mae                              1.0
# train_mse                              1.0
# train_rmse                             1.0
# val_acc                                0.0
# val_f1                                 0.0
# val_mae                                1.0
# val_mse                                1.0
# val_rmse                               1.0
# test_acc                               0.0
# test_f1                                0.0
# ...
